# %% [markdown]
# # Sela Gordon
# # 7/14/2019
# # GEOG 682 LAB 4

# %%
import rasterio
from rasterio import plot
import matplotlib.pyplot as plt

# %%
satdat1 = rasterio.open("image1.tif")
satdat2 = rasterio.open("image2.tif")

# %%
plot.show(satdat1, cmap='terrain')
plot.show(satdat2, cmap='terrain')

# %%
#Code that confirms that both Sentinel-2 scenes have the same coordinate reference system. Use a Markup cell to show the name of this CRS.
if satdat1.crs== satdat2.crs:
    print ("Yes both scenes have the same coordinate system" )
    print (satdat1.crs)
    print (satdat2.crs)
# Out:
# Yes both scenes have the same coordinate system
# EPSG:32618
# EPSG:32618

# %% [markdown]
# # EPSG:32618 is WGS 84 / UTM zone 18N

# %%
# Code that creates a plot showing all of the bands in image1 individually including an appropriate title and colormap for each.

fig, (axr, axg, axb) = plt.subplots(1,3, figsize=(20,5))
plot.show((satdat1, 3), ax=axr, cmap='Reds', title='red channel')
plot.show((satdat1, 2), ax=axg, cmap='Greens', title='green channel')
plot.show((satdat1, 1), ax=axb, cmap='Blues', title='blue channel')

# %%
files_to_mosaicx = []

# %%
files_to_mosaicx.append(satdat1)
files_to_mosaicx.append(satdat2)

# %%
files_to_mosaicx
# Out:
# [<open DatasetReader name='image1.tif' mode='r'>,
#  <open DatasetReader name='image2.tif' mode='r'>]

# %%
from rasterio.merge import merge
mosaic, out_trans = merge(files_to_mosaic)

# %%
from rasterio.plot import show
show(mosaic, cmap='terrain')
